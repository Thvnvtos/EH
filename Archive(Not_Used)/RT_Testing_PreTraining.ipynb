# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.losses import CategoricalCrossentropy
from network import NetCNN1D
from tensorflow.keras.callbacks import ModelCheckpoint

from mne.decoding import CSP
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split

import numpy as np
import sys, os

import dataset_NewEEG
from config_NewEEG import Config

import matplotlib.pyplot as plt


import pandas as pd
import pickle


config = Config()



# Choose from: 'CLeft', 'CRight', 'CUp' and 'CDown'
config.used_classes = ['CLeft', 'CRight']
config.session_type = 'S3'
session_ID_test = 1


config.t_start = 0 
config.t_end = 3.0

window_size = 2.0
stride = 0.1


config.n_csp_components = 3

# All available channels = ['FC3', 'FCz', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CPz', 'CP4']
config.used_channels = ['FC3', 'FCz', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CPz', 'CP4']


config.start = int(config.t_start * 250)
config.t_end = int(config.t_end * 250)


X, y = dataset_NewEEG.session_sliced_dataset(config ,f'I{session_ID_test:02d}', window_size, stride)

shuffle_indices = np.random.permutation(len(y))

X = X[shuffle_indices]
y = y[shuffle_indices]

X, X_test, y, y_test = train_test_split(X, y, test_size=0.25, random_state=11)

print(X.shape)
print(X_test.shape)
# Out:
# WARNING:tensorflow:From c:\Users\Hammo\OneDrive\Desktop\Neurobus\eh-venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# (206, 13, 500)
# (69, 13, 500)

# %%
crossValidation_KF = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)


acc = []
Y_preds = []


best_model = None
best_acc = 0
best_fold_idx = 0
best_csp = None

for fold_idx, (train_index, valid_index) in enumerate(crossValidation_KF.split(X, y)):
    X_train = X[train_index]
    Y_train = y[train_index]
    X_valid = X[valid_index]
    Y_valid = y[valid_index]
    
    old_stdout = sys.stdout
    sys.stdout = open(os.devnull, 'w')


    csp = CSP(n_components=config.n_csp_components, reg=None, log=None, norm_trace=False, transform_into='csp_space')

    X_train = csp.fit_transform(X_train, Y_train)
    X_valid = csp.transform(X_valid)


    X_train = X_train.transpose(0, 2, 1)
    X_valid = X_valid.transpose(0, 2, 1)

    Y_train = tf.keras.utils.to_categorical(Y_train, num_classes = 2)
    Y_valid = tf.keras.utils.to_categorical(Y_valid, num_classes = 2)



    model = NetCNN1D() 


    model.compile(
            loss= CategoricalCrossentropy(from_logits=True, label_smoothing=0.05),
            optimizer=keras.optimizers.Adam(learning_rate=1e-4, weight_decay = 2e-5), 
            metrics=[keras.metrics.CategoricalAccuracy(name='acc')]
    ) 



    sys.stdout.close()
    sys.stdout = old_stdout



    checkpoint_cb = ModelCheckpoint(f'best_model_fold_{fold_idx}.tf', save_best_only=True, monitor='val_acc', mode='max', verbose=0, save_format='tf')

    history = model.fit(X_train, Y_train, validation_data=(X_valid, Y_valid), epochs=100, batch_size=16, verbose=0, callbacks=[checkpoint_cb])


    val_acc = max(history.history['val_acc'])
    acc.append(val_acc)

    if val_acc > best_acc:
        best_acc = val_acc
        best_model = model
        best_fold_idx = fold_idx
        best_csp = csp  



    
    plt.figure(figsize=(15,5))
    plt.title(f"subject = {0} | N_examples = {X_train.shape[0]} | {max(history.history['val_acc'])} ")

    plt.subplot(1,2,1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.legend(["Train Loss", "Val Loss"])

    plt.subplot(1,2,2)
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.legend(["Train Acc", "Val Acc"])



if best_model is not None:
    best_model.save('best_model.tf', save_format='tf')
    print(f"Best model saved (Fold {best_fold_idx}) with validation accuracy: {best_acc:.4f}")

    with open('csp.pkl', 'wb') as f:
        pickle.dump(best_csp, f)




print("\n\n ================================== \n")
print(f"{100*np.mean(acc):.2f}% +- {100*np.std(acc):.1f}")
# Out:
# WARNING:tensorflow:From c:\Users\Hammo\OneDrive\Desktop\Neurobus\eh-venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Hammo\OneDrive\Desktop\Neurobus\eh-venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_0.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_1.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_2.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_3.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model_fold_4.tf\assets
# INFO:tensorflow:Assets written to: best_model.tf\assets
# INFO:tensorflow:Assets written to: best_model.tf\assets
# Best model saved (Fold 1) with validation accuracy: 0.8293
#
#
#  ==================================
#
# 81.57% +- 1.8

# %%
model_trained = tf.keras.models.load_model('best_model.tf')
model_trained.trainable = False 

with open('csp.pkl', 'rb') as f:
    csp_trained = pickle.load(f)



X_test = csp_trained.transform(X_test)
X_test = X_test.transpose(0, 2, 1)

y_test = tf.keras.utils.to_categorical(y_test, num_classes = 2)
# Out:
# WARNING:tensorflow:From c:\Users\Hammo\OneDrive\Desktop\Neurobus\eh-venv\lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# WARNING:tensorflow:From c:\Users\Hammo\OneDrive\Desktop\Neurobus\eh-venv\lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.

# %%
model_trained.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4905 - acc: 0.7826
# [0.49049896001815796, 0.782608687877655]
